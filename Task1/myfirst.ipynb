# %% [markdown]
# # Questions Task1
#
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: Vangelis
# * Username: Tsivgoulis
# * Student number: S5641543
# * Group (AS1, etc.): As1
#
# -----

# %%
# Leave unaltered
totalpoints = currentpoints = 0

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#T1-section:-Course-manual-(1pt)" data-toc-modified-id="T1-section:-Course-manual-(1pt)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>T1 section: Course manual (1pt)</a></span><ul class="toc-item"><li><span><a href="#Short-questions-(1pt)" data-toc-modified-id="Short-questions-(1pt)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Short questions (1pt)</a></span></li><li><span><a href="#Joining-Rocket-chat-(1pt)" data-toc-modified-id="Joining-Rocket-chat-(1pt)-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Joining Rocket chat (1pt)</a></span></li></ul></li><li><span><a href="#T1-section:-Python-variables" data-toc-modified-id="T1-section:-Python-variables-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>T1 section: Python variables</a></span><ul class="toc-item"><li><span><a href="#Augmented-assignment-operators-(1pt)" data-toc-modified-id="Augmented-assignment-operators-(1pt)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Augmented assignment operators (1pt)</a></span></li><li><span><a href="#Energy-of-a-single-photon-(2-pt)" data-toc-modified-id="Energy-of-a-single-photon-(2-pt)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Energy of a single photon (2 pt)</a></span></li><li><span><a href="#Gravitational-pull-(2-pt)" data-toc-modified-id="Gravitational-pull-(2-pt)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Gravitational pull (2 pt)</a></span></li><li><span><a href="#Kepler's-third-law-(4-pt)" data-toc-modified-id="Kepler's-third-law-(4-pt)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Kepler's third law (4 pt)</a></span></li></ul></li><li><span><a href="#T1-section:-Working-with-the-Linux-operating-system" data-toc-modified-id="T1-section:-Working-with-the-Linux-operating-system-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>T1 section: Working with the Linux operating system</a></span><ul class="toc-item"><li><span><a href="#Command-line-exercises-(2-pt)" data-toc-modified-id="Command-line-exercises-(2-pt)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Command line exercises (2 pt)</a></span></li></ul></li><li><span><a href="#T1-section:-Transferring-files-to-and-from-Kapteyn" data-toc-modified-id="T1-section:-Transferring-files-to-and-from-Kapteyn-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>T1 section: Transferring files to and from Kapteyn</a></span><ul class="toc-item"><li><span><a href="#Upload-a-file-to-Kapteyn-(3-pt)" data-toc-modified-id="Upload-a-file-to-Kapteyn-(3-pt)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Upload a file to Kapteyn (3 pt)</a></span></li></ul></li><li><span><a href="#The-Kapteyn-remote-desktop" data-toc-modified-id="The-Kapteyn-remote-desktop-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>The Kapteyn remote desktop</a></span><ul class="toc-item"><li><span><a href="#(Laptop-or-Kapteyn-PC)-Create-a-directory-structure-for-your-tasks-(2-pt)" data-toc-modified-id="(Laptop-or-Kapteyn-PC)-Create-a-directory-structure-for-your-tasks-(2-pt)-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>(Laptop or Kapteyn PC) Create a directory structure for your tasks (2 pt)</a></span></li><li><span><a href="#(Laptop-or-Kapteyn-PC)-Copy-you-first-notebook-to-another-directory-(1-pt)" data-toc-modified-id="(Laptop-or-Kapteyn-PC)-Copy-you-first-notebook-to-another-directory-(1-pt)-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>(Laptop or Kapteyn PC) Copy you first notebook to another directory (1 pt)</a></span></li><li><span><a href="#Milestone-question:-(Remote-desktop-or-Kapteyn-PC)-Configuring-Dolphin-and-(3pt)" data-toc-modified-id="Milestone-question:-(Remote-desktop-or-Kapteyn-PC)-Configuring-Dolphin-and-(3pt)-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Milestone question: (Remote desktop or Kapteyn PC) Configuring Dolphin and (3pt)</a></span></li><li><span><a href="#Milestone-question:-Script-execution-(2-pt)" data-toc-modified-id="Milestone-question:-Script-execution-(2-pt)-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Milestone question: Script execution (2 pt)</a></span></li></ul></li><li><span><a href="#T1-section:-Exercises-for-the-command-line" data-toc-modified-id="T1-section:-Exercises-for-the-command-line-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>T1 section: Exercises for the command line</a></span><ul class="toc-item"><li><span><a href="#Abreviation-ASCII-(1-pt)" data-toc-modified-id="Abreviation-ASCII-(1-pt)-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Abreviation ASCII (1 pt)</a></span></li><li><span><a href="#Abreviation-URL-(1-pt)" data-toc-modified-id="Abreviation-URL-(1-pt)-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Abreviation URL (1 pt)</a></span></li><li><span><a href="#Mail-forwarding-(1-pt)" data-toc-modified-id="Mail-forwarding-(1-pt)-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Mail forwarding (1 pt)</a></span></li><li><span><a href="#Internet-security-(1pt)" data-toc-modified-id="Internet-security-(1pt)-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Internet security (1pt)</a></span></li><li><span><a href="#Using-'man'-pages-(1-pt)" data-toc-modified-id="Using-'man'-pages-(1-pt)-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Using 'man' pages (1 pt)</a></span></li><li><span><a href="#File-contents-(1-pt)" data-toc-modified-id="File-contents-(1-pt)-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>File contents (1 pt)</a></span></li><li><span><a href="#Directory-structure-(1-pt)" data-toc-modified-id="Directory-structure-(1-pt)-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Directory structure (1 pt)</a></span></li><li><span><a href="#Changing-directories-with-shortcuts-(1-pt)" data-toc-modified-id="Changing-directories-with-shortcuts-(1-pt)-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Changing directories with shortcuts (1 pt)</a></span></li><li><span><a href="#Symbolic-links-(1-pt)" data-toc-modified-id="Symbolic-links-(1-pt)-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Symbolic links (1 pt)</a></span></li><li><span><a href="#Wildcards-(2-pt)" data-toc-modified-id="Wildcards-(2-pt)-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Wildcards (2 pt)</a></span></li><li><span><a href="#Saving-search-time-with-TAB-key-(1-pt)" data-toc-modified-id="Saving-search-time-with-TAB-key-(1-pt)-6.11"><span class="toc-item-num">6.11&nbsp;&nbsp;</span>Saving search time with TAB key (1 pt)</a></span></li><li><span><a href="#Checking-out-the-bulk-disk-on-virgo01-(1-pt)" data-toc-modified-id="Checking-out-the-bulk-disk-on-virgo01-(1-pt)-6.12"><span class="toc-item-num">6.12&nbsp;&nbsp;</span>Checking out the bulk disk on virgo01 (1 pt)</a></span></li><li><span><a href="#File-permissions-(2-pt)" data-toc-modified-id="File-permissions-(2-pt)-6.13"><span class="toc-item-num">6.13&nbsp;&nbsp;</span>File permissions (2 pt)</a></span></li><li><span><a href="#Checking-available-quota-(1-pt)" data-toc-modified-id="Checking-available-quota-(1-pt)-6.14"><span class="toc-item-num">6.14&nbsp;&nbsp;</span>Checking available quota (1 pt)</a></span></li><li><span><a href="#Graphical-overview-of-disk-usage-(1-pt)" data-toc-modified-id="Graphical-overview-of-disk-usage-(1-pt)-6.15"><span class="toc-item-num">6.15&nbsp;&nbsp;</span>Graphical overview of disk usage (1 pt)</a></span></li><li><span><a href="#Advanced-use-of-command-find-(1-pt)" data-toc-modified-id="Advanced-use-of-command-find-(1-pt)-6.16"><span class="toc-item-num">6.16&nbsp;&nbsp;</span>Advanced use of command <code>find</code> (1 pt)</a></span></li><li><span><a href="#Finding-strings-in-files-with-command-grep-(1-pt)" data-toc-modified-id="Finding-strings-in-files-with-command-grep-(1-pt)-6.17"><span class="toc-item-num">6.17&nbsp;&nbsp;</span>Finding strings in files with command <code>grep</code> (1 pt)</a></span></li><li><span><a href="#Output-of-ls-to-file-(1-pt)" data-toc-modified-id="Output-of-ls-to-file-(1-pt)-6.18"><span class="toc-item-num">6.18&nbsp;&nbsp;</span>Output of <code>ls</code> to file (1 pt)</a></span></li><li><span><a href="#Information-about-processes-(1-pt)" data-toc-modified-id="Information-about-processes-(1-pt)-6.19"><span class="toc-item-num">6.19&nbsp;&nbsp;</span>Information about processes (1 pt)</a></span></li></ul></li><li><span><a href="#T1-section:-The-Kapteyn-Network" data-toc-modified-id="T1-section:-The-Kapteyn-Network-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>T1 section: The Kapteyn Network</a></span><ul class="toc-item"><li><span><a href="#Kapteyn-network-zones-(1-pt)" data-toc-modified-id="Kapteyn-network-zones-(1-pt)-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Kapteyn network zones (1 pt)</a></span></li></ul></li><li><span><a href="#Commands-and-applications" data-toc-modified-id="Commands-and-applications-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Commands and applications</a></span><ul class="toc-item"><li><span><a href="#Path-finding-(1-pt)" data-toc-modified-id="Path-finding-(1-pt)-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Path finding (1 pt)</a></span></li><li><span><a href="#(Milestone-question)-Execute-script-(3-pt)" data-toc-modified-id="(Milestone-question)-Execute-script-(3-pt)-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>(Milestone question) Execute script (3 pt)</a></span></li></ul></li><li><span><a href="#T1-section:--Python-simple-input-and-output" data-toc-modified-id="T1-section:--Python-simple-input-and-output-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>T1 section:  Python simple input and output</a></span><ul class="toc-item"><li><span><a href="#Print-function-(1-pt)" data-toc-modified-id="Print-function-(1-pt)-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Print function (1 pt)</a></span></li><li><span><a href="#(Milestone-question)-Magnitude-calculations-(3-pt)" data-toc-modified-id="(Milestone-question)-Magnitude-calculations-(3-pt)-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>(Milestone question) Magnitude calculations (3 pt)</a></span></li></ul></li><li><span><a href="#Finishing-up" data-toc-modified-id="Finishing-up-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Finishing up</a></span></li><li><span><a href="#T.A.-Grading" data-toc-modified-id="T.A.-Grading-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>T.A. Grading</a></span></li></ul></div>

# %% [markdown]
# ![1q1_question.png](attachment:question.png)
#
#
# ## T1 section: Course manual (1pt)

# %% [markdown]
# ### Short questions (1pt)
# In one cell, write answers to the questions below. Use a bit of Markdown
# to make a nice layout.
#
# 1. When does my Kapteyn computer account expire?
# 1. Where is the list with tasks for which I have to write a report?
# 1. What is the email address of the lecturer?
# 1. What kind of information can I find in my personal grading record?
# 1. To which group (AS1, etc.) am I assigned according to the personal grading record?
# 1. Who is my T.A. and what is his/her mail address for sending my reports?
# 1. When are the scheduled sessions for my group?
#
# **Answer**:

# %% [markdown]
# 1. The expiration date of my account is set to the end of the current academic year 21 August 2024
# 1. The list with the tasks for which I have to write a report on are located on the table of contents in the 'Tasks '
# 1.vogelaar@astro.rug.nl
# 1. In the personal grading record we can find the grades for the tasks , Midterm , Final grade and the T.A. email.
# 1. AS1
# 1. Ioana Balnit ibalint@astro.rug.nl
# 1. Tuesday 9-12 , Wednesday 14-17, Friday 11-14

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Leave unaltered
# ----> 2 totalpoints += 1
#       3 currentpoints += 0.0
#
# NameError: name 'totalpoints' is not defined

# %% [markdown]
# ### Joining Rocket chat (1pt)
#
# Join the  *prognum-students* group in the Kapteyn chat facility using the link:
# <https://chat.astro.rug.nl/invite/GhrByP>
#
# 1. When joining, write the message 'ready to start'. We will acknowledge this in your personal grading record.
# 2. How many members of the chat channel *prognum-students* are online at this moment (look in Rocket chat for icon 'Members')?
#
# **Answer**:

# %% [markdown]
# 20 students

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ![1q2_question.png](attachment:question.png)
#
# ##  T1 section: Python variables

# %% [markdown]
# ### Augmented assignment operators (1pt)
#
# Use repeatedly the assignment operator ``*=`` to calculate the factorial of 6 (i.e. ``6!``)
#
# **Answer**:

# %%
# Out:
#   Cell In[2], line 1
#     *=6
#     ^
# SyntaxError: invalid syntax

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Energy of a single photon (2 pt)
#
# $$E=h \frac{c}{\lambda}$$
#
# Use Python code to find the energy (in Joule) of a 100 TeV photon with a frequency of
# $2.42 \times 10^{28}\ \rm{Hz}$
# Use Python variables for all quantities.
#
# **Answer**:

# %% [markdown]
# from scipy.constants import  h
#
# f=2.42*10e28
# E=h*f
#
# print ("h ", h)
# print ("E = " , E)

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0

# %% [markdown]
# ### Gravitational pull (2 pt)
#
# $$F=G \frac{m_1m_2}{r^2}$$
#
# What is the gravitational pull between Moon and Earth when given:
#
# * Mass Moon  $7.342 \times 10^{22}$   kg
# * Mass Earth $5.9722 \times 10^{24}$ kg
# * Distance between Earth and Moon: $385000.6$ km
#
# Use Python variables for all quantities.
#
# **Answer**:

# %% [markdown]
# G = 6.67408e-11
# m1= 7.342*10e22
# m2= 5.9722*10e24
# r= 385000.6
#
# F =G * ((m1*m2)/r**2)
#
# print( " F = ", F, "N")

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0

# %% [markdown]
# ### Kepler's third law (4 pt)
#
#
# According to Kepler's third law, the square of the period ``P`` of the orbit of the planet is
# proportional to the cube of the semi
# major axis (``a``) of an elliptical orbit (which is half the distance of the
# longest axis of an ellipse).
# After applying Newton's (1642-1727) Laws of Motion and Newton's Law of Gravity
# one can derive the more general form:
#
# $$\boxed{P^2 = \frac{4\pi^2}{G(m_1+m_2)} a^3}$$
#
# where ``G`` is the gravitational constant, ``a`` the distance to the Sun, ``P`` is
# the period for one orbit (i.e. one year),
# ``m1`` is the mass of the heaviest and ``m2`` is the mass of
# the lighter body.
#
# Given this information and the code template below, we ask
# you to calculate an estimate of the mass of Sun and Earth combined.
# Use Python variables with the same name as in the above formula.
# The answer is in fact the mass of the Sun because the mass of Earth is
# almost a million times smaller than that of the Sun and therefore negligible.
#
# Start your code with the line ``from scipy.constants import G, pi``
# to define the values for $G$ and $\pi$.
#
# Answer: $(m_1+m_2) \approx 2\cdot10^{30} \rm{kg}$
#
# **Your solution**:

# %% [markdown]
# from scipy.constants import G, pi
# a= 1.496e8
# P= 3154e7
# M=4*pi**2*a**3/G*P**2
# print (" M = ", M)

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 0

# %% [markdown]
# ![1q3_question.png](attachment:question.png)
#
# ##  T1 section: Working with the Linux operating system

# %% [markdown]
# ###  Command line exercises (2 pt)
#
# Online: Open a terminal on the Jupyter Hub.
# On campus: Open a terminal on your desktop (e.g. ``konsole``)
#
# 1. Write ``echo $SHELL`` on the command line and press ``Enter``. What is the result?
# 1. What is the output of command: ``ls``?
# 1. One can give options after a command. In what does the output of ``ls -rtl`` differ
#    from ``ls``? It is not needed to find what the options mean, just describe what is different.
# 1. With ``touch a.txt`` one creates a new and empty file. How do you check that the file
#    has been created?
# 1. What is the result of ``cp a.txt b.txt``
# 1. What is the result of ``mv b.txt c.txt``
# 1. What is the result of ``mkdir PROGNUM``
# 1. What is the result of ``cd PROGNUM``
# 1. Create a new directory (folder) called ``Task1`` in folder PROGNUM
# 1. What happens if you are in folder ``Task1`` and enter ``cp ../../a.txt .``  (note the last dot)
# 1. What is the result of ``cd ../..`` followed by ``ls``
# 1. Remove (permanently) the file ``a.txt`` with command ``rm a.txt``
#    How can you check that is has been removed??
#
# **Answers**:

# %% [markdown]
# 1. /bin/bash
# 1. Desktop Documents Download Music Pictures Public Templates Video
# 1. It provides time stamps for the apprementioned options
# 1.we type the command ls and we can see it
# 1. a.txt  Desktop    Downloads  Pictures  Templates
# b.txt  Documents  Music      Public    Videos
# 1.mv: cannot stat 'b.text': No such file or directory
# 1.a.txt  Desktop    Downloads  Pictures  Public     Videos
# b.txt  Documents  Music      PROGNUM   Templates
# 1.[etsivgoulis@hydra08 PROGNUM]$
# 1.touch Task1
# 1.bash: cp../../a.text: No such file or directory
# 1.bash: cd../../ls: No such file or directory
# 1. [etsivgoulis@hydra08 PROGNUM]$ ls
# Task1

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0

# %% [markdown]
# ![1q4_question.png](attachment:question.png)
#
# ##  T1 section: Transferring files to and from Kapteyn

# %% [markdown]
# ### Upload a file to Kapteyn (3 pt)
#
# Here we assume you use your laptop and that you installed and configured Filezilla!
#
# * On the PC at Kapteyn, Download this notebook as a Python file (``.py``). Give it the name ``myfirst.py``.
# * This file will be stored somewhere om in your directory tree so remember where you stored it!
# * Install and configure ([see Filezilla howto](https://www.astro.rug.nl/intranet/courses/PROGNUM2023/build/html/Howto/Filezilla/filezilla.html)) on your laptop if you did not yet do this.
# * Start Filezilla on yor laptop and download ``myfirst.py`` to it.
#
#
# Note that your home folder at Kapteyn will show up as
# ``/Users/users/xxxxxxx``  where ``xxxxxxx`` is your username (e.g. */Users/users/vogelman*).
#
# Make a screendump of Filezilla showing the downloaded file in both panels.
# Upload that file to Kapteyn in the directory where you started the questions notebook and insert the image in the
# questions notebook (Edit--> Insert Image)
#
# **Answer**:

# %% [markdown]
# ![Screenshot%202024-02-07%20143855.png](attachment:Screenshot%202024-02-07%20143855.png)

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0

# %% [markdown]
# ![1q5_question.png](attachment:question.png)
#
# ##   T1 section: The Kapteyn remote desktop

# %% [markdown]
# ### (Laptop or Kapteyn PC) Create a directory structure for your tasks (2 pt)
#
# **You need to login to the remote Kapteyn Desktop (oVirt) from either a laptop or a Virgo/Hydra computer.**
#
# For this exercise you need some of the commands from previous assignments.
# Create the directory structure as described in the Task documentation (with *PROGNUM* and then *Task1*, *Task2* etc.)
# Include the necessary commands in your report.
#
# Check your structure with command:
#
# ``tree -d .``
#
# when you are in the Home directory. Please note the dot in the command!
#
# <font color='red'>Important</font> The result of your tree must be exactly as described.
# Our applications that check various code that you will
# create, assume per task the locations that we described above. So take care of the right names
# including the capitals!
#
# If our application that checks for files
# cannot find a file, your report cannot be graded. A note will be made in your
# [Personal grading record](https://www.astro.rug.nl/intranet/prognumadmin.php)
#
# **_NOTE:_** If your grading record shows that you need to repair something, then this has priority over continuing with the next task!
#
# Show the output of the ``tree`` command in this notebook.
#
# **Answer**:

# %% [markdown]
# etsivgoulis@hydra15 ~]$ tree -d .
# .
# ├── Desktop
# ├── Documents
# ├── Downloads
# ├── Music
# ├── Pictures
# ├── PROGNUM
# │   ├── Task1
# │   ├── Task2
# │   ├── Task3
# │   ├── Task4
# │   ├── Task5
# │   ├── Task6
# │   ├── Task7
# │   └── Task8
# ├── Public
# ├── Templates
# └── Videos
#
#
# 17 directories
# [etsivgoulis@hydra15 ~]$

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0

# %% [markdown]
# ### (Laptop or Kapteyn PC) Copy you first notebook to another directory (1 pt)
#
# * Stop your current notebook (see *Introduction to Jupyter notebooks and the Kapteyn Hub*, in TOC-->How-to's)
# * Copy your current notebook to the directory ``PROGNUM/Task1``.
# * Start Jupyter again and in the Files overview navigate to ``PROGNUM/Task1``.
# * Select the copied notebook, open it and work further with this version.
# * Remove the original file from your home directory so that we can check that you were successful.
#
# Copy the output of command ``ls`` in directory ``PROGNUM/Task1``
#
# **Answer**:

# %% [markdown]
# etsivgoulisTask1(1)-Copy1.ipynb'

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Milestone question: (Remote desktop or Kapteyn PC) Configuring Dolphin and (3pt)
#
# **Remember, a milestone question is a question for which the answer must be sufficient and correct.
# It monitors the requirement that you have made an important step. Your T.A. will require a second attempt if the answers are not accurate enough. The original grade will not change in that case.**
#
# ![1ma_milestone.jpeg](attachment:milestone.jpeg)
#
# On a Kapteyn PC or in a remote desktop, start application ``dolphin``. This is a so called file manager.
# Start Dolphin and configure it according to the image below.

# %% [markdown]
# ![dolphinconfig.png](attachment:dolphinconfig.png)
#
#
# Make a screendump of Dolphin's window with application `ksnapshot` (on newer systems called: `spectacle`),
# Dolphin should show two panes and in one of the panes, the contents of directory ``PROGNUM/Task1`` should be displayed.
#
# Embed the image in this notebook.
#
# **Embedded image**:

# %% [markdown]
# ![Screenshot%20from%202024-02-09%2013-33-07.png](attachment:Screenshot%20from%202024-02-09%2013-33-07.png)

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0

# %% [markdown]
# ### Milestone question: Script execution (2 pt)
#
# ![1mb_milestone.jpeg](attachment:milestone.jpeg)
#
# On your remote desktop or on a Kapteyn PC, open a terminal (*konsole*). On the command line, change directory
# to ``PROGNUM/Task1``. Earlier, you downloaded the script ``myfirst.py``. Now start this Python program on the command line with:
#
# ``python myfirst.py``
#
# The output is given on the terminal.
# Embed a screendump in your report.
#
# **Embedded image**:

# %% [markdown]
# ![Screenshot%20from%202024-02-07%2016-31-15.png](attachment:Screenshot%20from%202024-02-07%2016-31-15.png)

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0

# %% [markdown]
# ![5question.png](attachment:question.png)
#
# ##  T1 section: Exercises for the command line

# %% [markdown]
# ### Abreviation ASCII (1 pt)
#
# 1. What does ASCII mean? Use the abbreviation server to find an answer.
#    When we talk about *plain text files*, we usually refer to *ASCII files*.
# 1. Mention a tool with which you can edit an ASCII file.
#
# **Answers**:

# %%
ASCII means American Standart Code for Information Interchange

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Abreviation URL (1 pt)
#
# 1. What does URL mean? Use the abbreviation server to find an answer.
# 2. Does a URL reveal whether a connection is secure or not?
#
# **Answers**:

# %%
Universal Resource Locator , a secure URL starts with hhtps

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Mail forwarding (1 pt)
#
# 1. Open your Kapteyn mail at: [Kapteyn Webmail](https://webmail.astro.rug.nl/)
# 2. If you prefer to receive mail from Kapteyn on another mail account, then follow the steps in Task1
#    to forward this mail. If you don't prefer this, then at least describe the steps how you should do this.
#
# **Answer**:

# %%
We start the Kapteyn webmailer, we click on the maintenance wheel , we select Filters and press add Filter.We enter our name in the pop up , skip the "Add a condition "option and we select "Vacation message" in the action section.After we enter the wanted email , check the "Do not stop processing rules "and press "Done"
# Out:
#   Cell In[1], line 1
#     We start the Kapteyn webmailer, we click on the maintenance wheel , we select Filters and press add Filter.We enter our name in the pop up , skip the "Add a condition "option and we select "Vacation message" in the action section.
#        ^
# SyntaxError: invalid syntax

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Internet security (1pt)
#
# Describe what phishing is and how to recognize a phishing mail.
#
# **Answer**:

# %%
Phishing is a type of social engineering attack often used to steal user data, including login credentials and credit card numbers.We can recognize a phishing email by the inconsistencies in email addresses, links and domain names.

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Using 'man' pages (1 pt)
#
# Find in the man pages the help information for command ``cp``. Give the command to copy directories recursively (i.e. including sub-folders also)
#
# **Answer**:

# %%
 -R, -r, --recursive
              copy directories recursively

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### File contents (1 pt)
#
# * Create a text file in your home directory (e.g. using kate) and fill it with some words.
# * Examine the contents of this text file using ``more``.
# * Use command ``file`` to check whether the file is text or a binary file?
#   Report the result of command ``file``
#
# **Answer**:

# %%
\[etsivgoulis@hydra08 ~]$ kate
[etsivgoulis@hydra08 ~]$ file
Usage: file [-bcCdEhikLlNnprsSvzZ0] [--apple] [--extension] [--mime-encoding]
            [--mime-type] [-e <testname>] [-F <separator>]  [-f <namefile>]
            [-m <magicfiles>] [-P <parameter=value>] [--exclude-quiet]
            <file> ...
       file -C [-m <magicfiles>]
       file [--help]

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Directory structure (1 pt)
#
# Take a look at the picture
# [UnixTree](https://www.astro.rug.nl/intranet/courses/PROGNUM2023/build/html/_images/UnixTree-11.png)
# in Task1 that shows a directory tree for Linux. Suppose this is the directory structure
# of your PC. In your home directory you have a folder called *Downloads*.
# Assume you are in this folder *Downloads*.
#
# 1. What will be the output of Unix command ``pwd``?
# 2. To which directories refer the notations ``.`` and ``..``? Check this with command ``ls``.
#
# **Answers**:

# %%
1. [etsivgoulis@hydra08 Downloads]$ pwd
/Users/users/etsivgoulis/Downloads
2. [etsivgoulis@hydra08 Downloads]$ .
bash: .: filename argument required
.: usage: . filename [arguments]
[etsivgoulis@hydra08 Downloads]$ ..
[etsivgoulis@hydra08 Downloads]$ ls
myfirst.py

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Changing directories with shortcuts (1 pt)
#
# Suppose you changed to a directory ``/net/virgo01/data/users/XXXXXXX`` where `XXXXXXX` is your username.
# Now you want to change to directory ``Desktop`` which is (or should be) a subdirectory of your home.
# Give the shortest command to do this.
#
# **Answer**:

# %%
cd ~\Desktop

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Symbolic links (1 pt)
#
# 1. Create in your home directory a symbolic link to  ``/net/virgo01/data/users/XXXXXXX`` where `XXXXXXX` is your username.
#    Give it the alias `VIRGO01` which is the student data server.
# 2. Execute command ``ls -l`` in your home directory, make a screendump of its output and embed the image in this notebook.
#
#
# **Answers**:

# %% [markdown]
# ![Screenshot%20from%202024-02-09%2012-02-41.png](attachment:Screenshot%20from%202024-02-09%2012-02-41.png)

# %% [markdown]
# The image should be proof that the command was successful. Having this shortcut is essential so both answers must be sufficient. If not, please ask for an improvement (which does not alter the credits).

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# # Wildcards (2 pt)
#
# What is the meaning of wildcard ``*``?
# Use the command ``touch`` to create some empty files with names that contain at least one digit and
# that end on ``.co``, ``.c`` and ``.o`` e.g.:
#
#     touch t.c
#     touch t1.c
#     touch t2.o
#     touch t3.co
#     touch t.co
#     touch t7b3.c
#     touch t66.oc
#
# * Describe the results of the command: ``ls *[0-9]*.[co]``.
# * What is the meaning of the square brackets ``[`` and ``]``?
# * And explain the difference between this
#   command and ``ls *[0-9]*.co``
#
# **Answer**:

# %%
1. etsivgoulis@hydra08 ~]$ man *
No manual entry for Desktop
No manual entry for Documents
No manual entry for Downloads
No manual entry for Music
No manual entry for Pictures
No manual entry for PROGNUM
No manual entry for Public
No manual entry for sieve
No manual entry for Templates
No manual entry for Videos
2. etsivgoulis@hydra08 ~]$ ls *[0-9]*.[co]
t1.c  t2.o  t7b3.c
we only get the files which contain numbers [0-9]and have either .c or .o 
3.The square brackets give results that contain one digit/letter of the bracket as seen in the apprimentioned example.
4.[etsivgoulis@hydra08 ~]$ ls *[0-9].co
t3.co
Here we see that only t3.co is given , thus when we dont include square brackets the result gives what we asked (.[co])

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0

# %% [markdown]
# ### Saving search time with TAB key (1 pt)
#
#
# 1. Assuming you created the files in the previous exercise,  type ``ls``, followed by the first letters of a filename and press TAB. Describe what happens. This mechanism is called  *file completion*.
#
# 2. On an empty command line, press the **arrow up** key and describe what happens. What happens when you press the arrow up- or down key after typing ``ls`` (without ``Enter``)?  This is an example of *history completion*.
#
# **Answers**:

# %%
[etsivgoulis@hydra08 ~]$ ls t.c 
.bash_history  Desktop/       .local/        Public/        t7b3.c
.bash_profile  Documents/     .mozilla/      sieve/         t.c
.bashrc        Downloads/     Music/         t1.c           t.co
.cache/        .ipython/      Pictures/      t2.o           Templates/
.config/       .jupyter/      .procmailrc    t3.co          Videos/
.cshrc         .lesshst       PROGNUM/       t66.oc       
2.when pressing the arrow up key on an empty command line it gives us commands used before. 
3. [etsivgoulis@hydra08 ~]$ ls -rtl

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Checking out the bulk disk on virgo01 (1 pt)
#
#
# ``cd`` to your data on Virgo01. Create (e.g. with ``touch``) a file called ``myverybigdataset``.
#
# Now type ``ls -l``
#
# 1. Make a screendump of what you see now in your terminal. The screendump should at least show the output of your ``ls -l`` command. Embed the result in your report.
# 2. For what purpose should you use the bulk disk?
#
# **Answers**:

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### File permissions (2 pt)
#
# Use section *Controlling access to your files and directories* in the
# [UNIXhelp for Users, access permissions](https://www.astro.rug.nl/Unixhelp/Pages/tasks/access_permissions.html)
# to read about the details of file protection and answer the following questions:
#
# 1. What do the characters **r**, **w** & **x** mean?
# 1. Create a dummy file with a text editor or with ``touch filename``  (*filename* can be any name). What is its file protection?
# 1. Describe how to use command ``chmod`` to change this protection such that the file is **only readable and writeable** for **you**, the owner.
# 1. Can you list the files in the home directory of another student?
# 1. Can you read the contents of the file ``.bashrc`` in the home directory of another student? What is the output if you attempt this?
# 1. Can you list the files of another student on `virgo01`?
#
# **Answers**:

# %%
1.r  read the file or directory
   w  write to the file or directory
   x  execute the file or search the directory
2.

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0

# %% [markdown]
# ### Checking available quota (1 pt)
#
# 1. Display your assigned quota using the command ``quota -s``. What do the numbers mean?
# 2. What does the option ``-s`` mean (use ``quota --help`` on the command line)?
#
# **Answers**:

# %%
etsivgoulis@hydra08 ~]$ quota -s
Disk quotas for user etsivgoulis (uid 1861400964): 
     Filesystem   space   quota   limit   grace   files   quota   limit   grace
homeserver.intra.astro.rug.nl:/users/users
                   284M   8192M   9216M            3283       0       0        
2. s, --human-readable[=units]  display numbers in human friendly units (MB, GB,
                              ...). Units can be also specified explicitely by
                              an optional argument in format [kgt],[kgt] where
                              the first character specifies space units and the
                              second character specifies inode units

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Graphical overview of disk usage (1 pt)
#
# Use ``fsview .`` or `ncdu` on the command line to find which file is currently taking the most of your disk space in your home directory
# and its sub directories? Report the name of the file and its size.
#
# **Answer**:

# %%
./cache 116.1MiB

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Advanced use of command ``find`` (1 pt)
#
# Compose a Unix command that finds all Python files in your home directory and its sub directories.
# (a pure Python file name usually ends on \*.py)
# You probably don't have any Python file so make some with a command similar to:
# ``touch t2.py t2.py fast.py slow.py``
#
# **Answer**:

# %%
find . name'*.py" -ls

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Finding strings in files with command ``grep`` (1 pt)
#
# Give the ``grep`` command and its options to look for the string *task*
# in all the files in your home directory and its sub-directories. Make the search case-insensitive.
# Include the command and a couple of lines of the output in a Markdown cell in your report.
#
# **Answer**:

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Output of ``ls`` to file (1 pt)
#
# What is the reason that the command: ``ls > ls.out`` generates a
# list of which 'ls.out' is also part? (try it if you don't believe it!).
#
# **Answer**:

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### Information about processes (1 pt)
#
# Describe the output of the composed command ``ps -ef | grep yourusername``
# (replace ``yourusername`` by your Linux username).
# There is no need to describe the exact meaning of the columns.
#
# **Answer**:

# %%
etsivgoulis@hydra08 ~]$ ps -ef | grep etsivgoulis
etsivgo+   13865   13283  0 13:45 pts/4    00:00:00 grep --color=auto etsivgoulis
etsivgo+ 4179409 4179406  0 10:58 ?        00:00:01 /usr/sbin/mysqld --defaults-file=/Users/users/etsivgoulis/.local/share/akonadi/mysql.conf --datadir=/Users/users/etsivgoulis/.local/share/akonadi/db_data/ --socket=/run/user/1861400964/akonadi/mysql.socket --pid-file=/run/user/1861400964/akonadi/mysql.pid
etsivgo+ 4180284 4180013  5 11:00 ?        00:08:49 /usr/lib64/firefox/firefox -new-tab file:///Users/users/etsivgoulis/.local/share/jupyter/runtime/nbserver-4180013-open.html
etsivgo+ 4190600 4180013  0 12:06 ?        00:00:01 /Software/users/modules/9/software/anaconda3/2023.03/bin/python -m ipykernel_launcher -f /Users/users/etsivgoulis/.local/share/jupyter/runtime/kernel-1e14c508-9da1-4483-bee3-235226f5b765.json

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ![1q6_question.png](attachment:question.png)
#
# ##  T1 section: The Kapteyn Network

# %% [markdown]
# ### Kapteyn network zones (1 pt)
#
# Assume you are at the institute with a laptop and are connected to the network in a *laptop* zone.
# What does the figure about the Kapteyn network in Task 1 tell you about access to ``virgo01`` via ``/net/virgo01`` then?
# Possible or not possible and why?
#
#
# **Answer**:

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ![1q7_question.png](attachment:question.png)
#
# ##  T1 section: Commands and applications

# %% [markdown]
# ### Path finding (1 pt)
#
# * Use Unix command ``which ds9`` to find the Unix path to the application DS9. Give the path in your report.
# * You can start the program by typing ``ds9`` on the command line. There is no need to type the
#   whole path.
# * Download FITS image [m101.fits](https://www.astro.rug.nl/intranet/courses/PROGNUM2023/build/html/Tasks/examples/m101.fits), copy it
#   with Filezilla to the directory PROGNUM/Task1 on your remote desktop and display
#   it from the command line by entering command ``ds9 m101.fits``.
# * Try different colour look up tables in ``ds9``.
#
# Pixel positions in the image correspond to a position in a World Coordinate System (WCS).
# ``ds9`` does this transformation for you.
#
# 1. Give WCS coordinates $(\alpha, \delta)$ for the approximate center of the galaxy.
#
# **Answer**:

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### (Milestone question) Execute script (3 pt)
# ![1m3_milestone.jpeg](attachment:milestone.jpeg)

# %% [markdown]
# ![1xa_executable.png](attachment:executable.png)
#
# Following all the steps in section *Adding a path to the search path* and subsequent sections in Task 1,
# implement ``mylisting`` and demonstrate that you can execute it from an
# arbitrary directory by embedding a screendump of its output in this notebook.
#
# **Screendump**:

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0

# %% [markdown]
# ##  T1 section:  Python simple input and output

# %% [markdown]
# ### Print function (1 pt)
#
# Run and explain the output of the code:
#
#     x1 = 10
#     x2 = 22/7
#     print(x1, end="")
#     print(x2, end="")
#
# **Answer**:

# %%
# Leave unaltered
totalpoints += 1
currentpoints += 0

# %% [markdown]
# ### (Milestone question) Magnitude calculations (3 pt)
#
# ![1md_milestone.jpeg](attachment:milestone.jpeg)
#
# Astronomers use the term apparent magnitude to describe how bright an object appears in the
# sky as seen from Earth.  In 150 BC, Hipparchus invented a scale where he assigned
# an apparent magnitude of 1 to the brightest stars in the sky, and he gave the dimmest
# stars he could see an apparent magnitude of 6. (Sun, Moon and planets exclude).
# The absolute magnitude is invented later when astronomers realized that the magnitude depends
# on the distance to an object.
# Therefore the absolute magnitude is defined as the apparent
# magnitude of an object if it was located at a distance of 10 parsecs.
#
# The relation between absolute magnitude (M), apparent magnitude (m) and distance (d) in parsec is:
#
# $$m - M = 5 \log_{10} d - 5$$
#
# when we know the absolute- and apparent magnitude of a star, we calculate the distance
# to that star with the formula:
#
# $$d(pc) = 10^{\frac{m-M}{5} + 1}$$
#
# 1 parsec is 3.26164 lightyear (ly).
#
# We can calculate the distance to Sirius in lightyears with the code:
#
#     # Sirius data
#     apparentMagnitude = -1.46
#     absoluteMagnitude = 1.45
#
#     # The distance is related to the magnitudes as m-M=5.Log(d/10)
#     # 1 Parsec = 3.26164 ly
#
#     m = apparentMagnitude
#     M = absoluteMagnitude
#
#     d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164
#
# 1. Copy this to an empty notebook. Expand it with interactive input with ``input()`` for both magnitudes and
#    print the resulting distance using an f-string in ``print()``.
#    Include the output for Sirius in your report.
# 2. Create a Python script (download notebook as ``.py`` file).
#    If you are not on campus, transfer the file to PROGNUM/Task1 at the institute.
# 3. Rename the file into ``magnitude.py`` and run it with:
#    ``python magnitude.py`` on the command line.
# 4. Include code and embed a screendump of its output in your report.
#
# **Answers**:

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0

# %% [markdown]
# ## Finishing up
#
# **Please read the section about your report in the task very carefully before mailing your work to a T.A.**
#
# ------

# %% [markdown]
# ## T.A. Grading

# %%
# Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1)
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
# Out:
# Total number of points: 54. Student score: 0.0.  Task Grade = 0.0
